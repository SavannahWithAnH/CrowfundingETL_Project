# %% [markdown]
# ### 2. Create the Campaign DataFrame
# Extract and transform the crowdfunding.xlsx Excel data to create a campaign DataFrame has the following columns:

# %%
#Data Extract
import pandas as pd
import regex as re
pd.options.display.max_colwidth = 200

# %%
crowdfunding_df = pd.read_excel('../Resources/crowdfunding.xlsx')
crowdfunding_df
# Out:
#      cf_id  contact_id                  company_name  \
# 0      147        4661    Baldwin, Riley and Jackson
# 1     1621        3765                      Odom Inc
# 2     1812        4187    Melton, Robinson and Fritz
# 3     2156        4941   Mcdonald, Gonzalez and Ross
# 4     1365        2199                 Larson-Little
# ..     ...         ...                           ...
# 995   2986        3684              Manning-Hamilton
# 996   2031        5784                    Butler LLC
# 997   1627        1498                      Ball LLC
# 998   2175        6073   Taylor, Santiago and Flores
# 999   1788        4939  Hernandez, Norton and Kelley
#
#                                              blurb    goal  pledged  \
# 0             Pre-emptive tertiary standardization     100        0
# 1                 Managed bottom-line architecture    1400    14560
# 2     Function-based leadingedge pricing structure  108400   142523
# ...

# %% [markdown]
# * The "cf_id" column - done
# * The "contact_id" column - done
# * The "company_name" column - done
# * The "blurb" column, renamed to "description" - done
# * The "goal" column, converted to the float data type - done
# * The "pledged" column, converted to the float data type - done
# * The "outcome" column - done
# * The "backers_count" column - done
# * The "country" column - done
# * The "currency" column - done
# * The "launched_at" column, renamed to "launch_date" and with the UTC times converted to the datetime format
# * The "deadline" column, renamed to "end_date" and with the UTC times converted to the datetime format
# * The "category_id" column, with unique identification numbers matching those in the "category_id" column of the category DataFrame
# * The "subcategory_id" column, with the unique identification numbers matching those in the "subcategory_id" column of the subcategory DataFrame
#
# ![image](https://github.com/SavannahWithAnH/Project-2/assets/126124356/a41de922-6bb9-41a2-aa76-3710624449e6)

# %%
#Data Transfromation
campaign_df = crowdfunding_df[['cf_id','contact_id', 'company_name', 'blurb', 'goal', 'pledged', 'outcome', 'backers_count', 'country', 'currency', 'launched_at', 'deadline', 'category & sub-category']]
campaign_df = campaign_df.rename(columns= {'blurb': 'description', 'launched_at': 'launch_date', 'deadline': 'end_date'})
campaign_df['goal'] = campaign_df['goal'].astype(float)
campaign_df['pledged'] = campaign_df['pledged'].astype(float)
campaign_df["end_date"] = pd.to_datetime(campaign_df["end_date"], unit='s').dt.strftime('%Y-%m-%d')
campaign_df["launch_date"] = pd.to_datetime(campaign_df["launch_date"], unit='s').dt.strftime('%Y-%m-%d')
campaign_df[['category_id', 'subcategory_id']] = campaign_df['category & sub-category'].str.split('/', n=1, expand=True)
campaign_df = campaign_df.drop('category & sub-category', axis=1)
campaign_df.head(10)
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
# 5   2057        5650                 Harris Group
# 6   1894        5889  Ortiz, Coleman and Mitchell
# 7   2669        4842                Carter-Guzman
# 8   1114        3280               Nunez-Richards
# 9    970        5468       Rangel, Holt and Jones
#
#                                      description      goal   pledged  \
# 0           Pre-emptive tertiary standardization     100.0       0.0
# 1               Managed bottom-line architecture    1400.0   14560.0
# 2   Function-based leadingedge pricing structure  108400.0  142523.0
# 3  Vision-oriented fresh-thinking conglomeration    4200.0    2477.0
# ...

# %% [markdown]
# Export the campaign DataFrame as campaign.csv and save it to your GitHub repository.

# %%
#importing csv and creating DataFrame for cat and subcat
category_path = pd.read_csv("/home/mo/Documents/UNC/Project-2/Cat & Subcat Savannah/Output/category.csv")
category_df = pd.DataFrame(category_path)
category_df
# Out:
#   category_id      category
# 0        cat1          food
# 1        cat2         music
# 2        cat3    technology
# 3        cat4       theater
# 4        cat5  film & video
# 5        cat6    publishing
# 6        cat7         games
# 7        cat8   photography
# 8        cat9    journalism

# %%
subcategory_path = pd.read_csv("/home/mo/Documents/UNC/Project-2/Cat & Subcat Savannah/Output/subcategory.csv")
subcategory_df = pd.DataFrame(subcategory_path)
subcategory_df
# Out:
#    subcategory_id        subcategory
# 0         subcat1        food trucks
# 1         subcat2               rock
# 2         subcat3                web
# 3         subcat4              plays
# 4         subcat5        documentary
# 5         subcat6     electric music
# 6         subcat7              drama
# 7         subcat8         indie rock
# 8         subcat9          wearables
# 9        subcat10         nonfiction
# 10       subcat11          animation
# 11       subcat12        video games
# 12       subcat13             shorts
# 13       subcat14            fiction
# 14       subcat15  photography books
# 15       subcat16   radio & podcasts
# 16       subcat17              metal
# 17       subcat18               jazz
# 18       subcat19       translations
# 19       subcat20         television
# 20       subcat21       mobile games
# 21       subcat22        world music
# 22       subcat23    science fiction
# 23       subcat24              audio

# %%
campaign_df = pd.merge(campaign_df, category_df, left_on='category_id', right_on='category', how='left')

#
campaign_df = pd.merge(campaign_df, subcategory_df, left_on='subcategory_id', right_on='subcategory', how='left')



campaign_df.head(10)
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
# 5   2057        5650                 Harris Group
# 6   1894        5889  Ortiz, Coleman and Mitchell
# 7   2669        4842                Carter-Guzman
# 8   1114        3280               Nunez-Richards
# 9    970        5468       Rangel, Holt and Jones
#
#                                      description      goal   pledged  \
# 0           Pre-emptive tertiary standardization     100.0       0.0
# 1               Managed bottom-line architecture    1400.0   14560.0
# 2   Function-based leadingedge pricing structure  108400.0  142523.0
# 3  Vision-oriented fresh-thinking conglomeration    4200.0    2477.0
# ...

# %%
#Data Export
campaign_df.to_csv(('./Output/crowdfunding.csv'), index=False)
